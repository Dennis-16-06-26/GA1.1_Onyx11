# %%
def add(a,b):
    return a + b

# %%
add(2,3)

# %%
add(355,11)

# %%
def sumlist(list):
    x = 0
    for i in list:
        x = add(x,i)
    return x

# %%
ages = [12, 13, 14, 15, 16, 17, 18]

sumlist(ages)
