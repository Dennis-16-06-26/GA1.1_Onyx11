# %%
def subtract(a,b):
    return a - b

# %%
subtract(6, 5)

# %%
def distance_from_zero(x):
    if x < 0:
        a =subtract(0,x)
    else:
        a = subtract(x,0)
    return a

# %%
distance_from_zero(-5)
